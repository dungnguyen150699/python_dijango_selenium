# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("HR_dataset.csv")
columnNames = df.columns.values
print(df)
print(columnNames)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
filterNumpy = columns != "left"
X = columnNames[filterNumpy]
Y = ["left"]

print(X,Y, sep="\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 filterNumpy = columns != "left"
#       2 X = columnNames[filterNumpy]
#       3 Y = ["left"]
#
# NameError: name 'columns' is not defined

# %%
print(type(df["left"].tolist()))
# Out:
# <class 'list'>

# %%
for idx,x in enumerate(X):
    print(idx,x)
    firstValue = df[x][0]
    try:
        float(firstValue)
        continue
    except:
        colNeedMapValue = set(df[x].tolist())
        dictoryMap = {}
        for idx1,item in enumerate(df[x]):
            dictoryMap[item] = idx1
        df[x] = df[x].map(dictoryMap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for idx,x in enumerate(X):
#       2     print(idx,x)
#       3     firstValue = df[x][0]
#
# NameError: name 'X' is not defined

# %%
print(df)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dtree = DecisionTreeClassifier()
dtree = dtree.fit(df[X.tolist()], df[Y])

tree.plot_tree(dtree, feature_names=X.tolist())
# Out:
# [Text(0.45473397482100814, 0.9782608695652174, 'satisfaction_level <= 0.465\ngini = 0.363\nsamples = 14999\nvalue = [11428, 3571]'),
#  Text(0.14249675652299265, 0.9347826086956522, 'number_project <= 2.5\ngini = 0.478\nsamples = 4183\nvalue = [1652, 2531]'),
#  Text(0.036903560616981405, 0.8913043478260869, 'last_evaluation <= 0.575\ngini = 0.213\nsamples = 1742\nvalue = [211, 1531]'),
#  Text(0.018451780308490703, 0.8478260869565217, 'last_evaluation <= 0.445\ngini = 0.104\nsamples = 1612\nvalue = [89, 1523]'),
#  Text(0.015376483590408918, 0.8043478260869565, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(0.021527077026572486, 0.8043478260869565, 'average_montly_hours <= 162.0\ngini = 0.063\nsamples = 1574\nvalue = [51, 1523]'),
#  Text(0.012301186872327135, 0.7608695652173914, 'average_montly_hours <= 125.5\ngini = 0.037\nsamples = 1546\nvalue = [29, 1517]'),
#  Text(0.009225890154245351, 0.717391304347826, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
# ...
